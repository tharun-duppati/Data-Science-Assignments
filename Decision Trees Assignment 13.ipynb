# %%
#---------------------------------------importing the data---------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("D:\\ExcelR Assignments\\Assignment 13\\heart_disease.xlsx",sheet_name="Heart_disease")
df
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
#------------------------------------------Exploratory Data Analysis (EDA)---------------------------------------------------

# %%
import matplotlib.pyplot as plt
plt.xlabel("age")
plt.ylabel("frequency")
plt.hist(df["age"],label="age")
plt.legend()

# %%
import matplotlib.pyplot as plt
plt.xlabel("trestbps")
plt.ylabel("frequency")
plt.hist(df["trestbps"])
# Out:
# (array([  1.,   0.,   0.,   0.,  14., 153., 396., 225.,  86.,  33.]),
#  array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
plt.xlabel("chol")
plt.ylabel("frequency")
plt.hist(df["chol"])
# Out:
# (array([172.,   6.,  60., 309., 247.,  85.,  17.,   7.,   3.,   2.]),
#  array([  0. ,  60.3, 120.6, 180.9, 241.2, 301.5, 361.8, 422.1, 482.4,
#         542.7, 603. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
plt.xlabel("thalch")
plt.ylabel("frequency")
plt.hist(df["thalch"])
# Out:
# (array([ 17.,  22.,  70., 106., 178., 169., 146., 129.,  61.,  10.]),
#  array([ 60. ,  74.2,  88.4, 102.6, 116.8, 131. , 145.2, 159.4, 173.6,
#         187.8, 202. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df["sex"],df["oldpeak"])
plt.xlabel("sex")
plt.ylabel("oldpeak")
# Out:
# Text(0, 0.5, 'oldpeak')

# %%
plt.bar(df["sex"],df["thalch"])
plt.xlabel("sex")
plt.ylabel("thalch")
# Out:
# Text(0, 0.5, 'thalch')

# %%
plt.bar(df["cp"],df["oldpeak"])
plt.xlabel("cp")
plt.ylabel("oldpeak")
# Out:
# Text(0, 0.5, 'oldpeak')

# %%
plt.xlabel("age")
plt.ylabel("trestbps")
plt.scatter(df["age"],df["trestbps"])

# %%
plt.xlabel("age")
plt.ylabel("chol")
plt.scatter(df["age"],df["chol"])

# %%
plt.xlabel("age")
plt.ylabel("thalch")
plt.scatter(df["age"],df["thalch"])

# %%
plt.xlabel("age")
plt.ylabel("oldpeak")
plt.scatter(df["age"],df["oldpeak"])

# %%
plt.xlabel("trestbps")
plt.ylabel("chol")
plt.scatter(df["trestbps"],df["chol"])

# %%
plt.xlabel("trestbps")
plt.ylabel("oldpeak")
plt.scatter(df["trestbps"],df["oldpeak"])

# %%
'''
There is a positive relationship between age and trestbps.
There is a positive relationship between age and chol.
There is a negative relationship between age and thalch.
There is a positive relationship between age and oldpeak.
There is a positive relationship between trestbps and chol.
There is a positive relationship between trestbps and oldpeak.

'''
# Out:
# '\nThere is a positive relationship between age and trestbps.\nThere is a positive relationship between age and chol.\nThere is a negative relationship between age and thalch.\nThere is a positive relationship between age and oldpeak.\nThere is a positive relationship between trestbps and chol.\nThere is a positive relationship between trestbps and oldpeak.\n\n'

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalch       0
# exang        0
# oldpeak     62
# slope        0
# thal         0
# num          0
# dtype: int64

# %%
#There are 62 missing values in oldpeak.Hence I am filling those missing values with their mean i.e., with the mean of oldpeak

# %%
df['oldpeak'].fillna(df['oldpeak'].mean(), inplace=True)
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# thal        0
# num         0
# dtype: int64

# %%
#There are no missing values now.

# %%
plt.boxplot(df["oldpeak"],vert=False)
plt.xlabel("oldpeak")
q1=df["oldpeak"].quantile(0.25)
q3=df["oldpeak"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["oldpeak"]<lw) | (df["oldpeak"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -2.25
# Upper Whisker length: 3.75
# Outliers: 16

# %%
plt.boxplot(df["trestbps"],vert=False)
plt.xlabel("trestbps")
q1=df["trestbps"].quantile(0.25)
q3=df["trestbps"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["trestbps"]<lw) | (df["trestbps"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: 84.0
# Upper Whisker length: 180.0
# Outliers: 22

# %%
plt.boxplot(df["chol"],vert=False)
plt.xlabel("chol")
q1=df["chol"].quantile(0.25)
q3=df["chol"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["chol"]<lw) | (df["chol"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: 36.875
# Upper Whisker length: 409.875
# Outliers: 187

# %%
plt.boxplot(df["thalch"],vert=False)
plt.xlabel("thalch")
q1=df["thalch"].quantile(0.25)
q3=df["thalch"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["thalch"]<lw) | (df["thalch"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: 61.0
# Upper Whisker length: 213.0
# Outliers: 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       908 non-null    int64
#  1   sex       908 non-null    object
#  2   cp        908 non-null    object
#  3   trestbps  908 non-null    int64
#  4   chol      908 non-null    int64
#  5   fbs       908 non-null    bool
#  6   restecg   908 non-null    object
#  7   thalch    908 non-null    int64
#  8   exang     908 non-null    object
#  9   oldpeak   908 non-null    float64
#  10  slope     908 non-null    object
#  11  thal      908 non-null    object
#  12  num       908 non-null    int64
# dtypes: bool(1), float64(1), int64(5), object(6)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#               age    trestbps        chol      thalch     oldpeak         num
# count  908.000000  908.000000  908.000000  908.000000  908.000000  908.000000
# mean    53.791850  133.430617  201.484581  135.957048    0.891253    1.008811
# std      9.158031   20.401608  112.097949   26.804929    1.055826    1.144436
# min     29.000000    0.000000    0.000000   60.000000   -2.600000    0.000000
# 25%     47.750000  120.000000  176.750000  118.000000    0.000000    0.000000
# 50%     54.000000  130.000000  224.000000  138.000000    0.800000    1.000000
# 75%     60.000000  144.000000  270.000000  156.000000    1.500000    2.000000
# max     77.000000  200.000000  603.000000  202.000000    6.200000    4.000000

# %%
df_final=df.drop("exang",axis=1)
df_final
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch   oldpeak        slope               thal  num
# ...

# %%
X_cat=df_final[["sex","cp","fbs","restecg","slope","thal","num"]]
X_cat
# Out:
#      sex  cp  fbs  restecg  slope  thal       num
# 0      1   3    1        0      0     0 -1.615852
# 1      1   1    0        1      1     0 -1.615852
# 2      1   0    0        1      1     0 -1.615852
# 3      1   3    0        0      1     0 -1.615852
# 4      1   0    0        1      1     0 -1.615852
# ..   ...  ..  ...      ...    ...   ...       ...
# 903    1   0    0        1      2     2  1.106214
# 904    1   0    0        2      1     2  1.106214
# 905    1   2    0        0      0     1 -0.254819
# 906    1   2    1        2      0     0 -1.615852
# 907    1   0    1        2      1     2  1.106214
#
# [908 rows x 7 columns]

# %%
X_cont=df_final.drop(X_cat,axis=1)
X_cont
# Out:
#           age  trestbps      chol    thalch   oldpeak
# 0    0.514416  2.320276  1.976894 -1.561352 -1.672770
# 1    0.514416  0.232258 -0.505844  0.013879 -0.224843
# 2    0.514416 -0.811752 -0.505844  0.013879 -0.224843
# 3    0.514416  2.320276 -0.505844 -1.561352 -0.224843
# 4    0.514416 -0.811752 -0.505844  0.013879 -0.224843
# ..        ...       ...       ...       ...       ...
# 903  0.514416 -0.811752 -0.505844  0.013879  1.223083
# 904  0.514416 -0.811752 -0.505844  1.589110 -0.224843
# 905  0.514416  1.276267 -0.505844 -1.561352 -1.672770
# 906  0.514416  1.276267  1.976894  1.589110 -1.672770
# 907  0.514416 -0.811752  1.976894  1.589110 -0.224843
#
# [908 rows x 5 columns]

# %%
list(X_cont)
# Out:
# ['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'num']

# %%
#------------------------------------------------Feature Engineering---------------------------------------------------

# %%
#Encoding categorical values
import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder,StandardScaler
le=LabelEncoder()
X_cat["sex"]=le.fit_transform(X_cat["sex"])
X_cat["cp"]=le.fit_transform(X_cat["cp"])
X_cat["fbs"]=le.fit_transform(X_cat["fbs"])
X_cat["restecg"]=le.fit_transform(X_cat["restecg"])
X_cat["slope"]=le.fit_transform(X_cat["slope"])
X_cat["thal"]=le.fit_transform(X_cat["thal"])
X_cat["num"]=le.fit_transform(X_cat["num"])

# %%
#Standardizing ontinuous data
ss=StandardScaler()
X_ss=ss.fit_transform(X_cont)
X_ss=pd.DataFrame(X_ss)
X_ss.columns=list(X_cont)
X_ss
# Out:
#           age  trestbps      chol    thalch   oldpeak
# 0    0.514416  2.320276  1.976894 -1.561352 -1.672770
# 1    0.514416  0.232258 -0.505844  0.013879 -0.224843
# 2    0.514416 -0.811752 -0.505844  0.013879 -0.224843
# 3    0.514416  2.320276 -0.505844 -1.561352 -0.224843
# 4    0.514416 -0.811752 -0.505844  0.013879 -0.224843
# ..        ...       ...       ...       ...       ...
# 903  0.514416 -0.811752 -0.505844  0.013879  1.223083
# 904  0.514416 -0.811752 -0.505844  1.589110 -0.224843
# 905  0.514416  1.276267 -0.505844 -1.561352 -1.672770
# 906  0.514416  1.276267  1.976894  1.589110 -1.672770
# 907  0.514416 -0.811752  1.976894  1.589110 -0.224843
#
# [908 rows x 5 columns]

# %%
#standardized data with label encoding columns

df_final=pd.concat([X_ss,X_cat],axis=1)
df_final
# Out:
#           age  trestbps      chol    thalch   oldpeak  sex  cp  fbs  restecg  \
# 0    0.514416  2.320276  1.976894 -1.561352 -1.672770    1   3    1        0
# 1    0.514416  0.232258 -0.505844  0.013879 -0.224843    1   1    0        1
# 2    0.514416 -0.811752 -0.505844  0.013879 -0.224843    1   0    0        1
# 3    0.514416  2.320276 -0.505844 -1.561352 -0.224843    1   3    0        0
# 4    0.514416 -0.811752 -0.505844  0.013879 -0.224843    1   0    0        1
# ..        ...       ...       ...       ...       ...  ...  ..  ...      ...
# 903  0.514416 -0.811752 -0.505844  0.013879  1.223083    1   0    0        1
# 904  0.514416 -0.811752 -0.505844  1.589110 -0.224843    1   0    0        2
# 905  0.514416  1.276267 -0.505844 -1.561352 -1.672770    1   2    0        0
# 906  0.514416  1.276267  1.976894  1.589110 -1.672770    1   2    1        2
# 907  0.514416 -0.811752  1.976894  1.589110 -0.224843    1   0    1        2
#
#      slope  thal  num
# ...

# %%
#-------------------------------------DecisionTreeClassification---------------------------------------------------------

# %%
Y=df_final["num"]
X=df_final.drop("num",axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (726, 11)
# X_test shape: (182, 11)
# Y_train shape: (726,)
# Y_test shape: (182,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier(criterion="gini")

model.fit(X_train, Y_train)

# Make predictions on the training set
Y_train_pred = model.predict(X_train)

# Make predictions on the testing set
Y_test_pred = model.predict(X_test)

# Calculate the training accuracy
train_accuracy = accuracy_score(Y_train, Y_train_pred)

# Calculate the testing accuracy
test_accuracy = accuracy_score(Y_test, Y_test_pred)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 1.0

# %%
# cross validation

training_acc = []
test_acc = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.3, random_state=i)
    model = DecisionTreeClassifier(criterion="gini",max_depth=6)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test = model.predict(X_test)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

print("Cross validation traning accuracy:", np.round(np.mean(training_acc),2))
print("Cross validation test accuracy:", np.round(np.mean(test_acc),2))
# Out:
# Cross validation traning accuracy: 1.0
# Cross validation test accuracy: 1.0

# %%
#---------------------------------------------------Hyperparameter Tuning---------------------------------------------------

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [1,2,3, 5, 7, 9],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)
grid_search.fit(X_train, Y_train)

best_clf = grid_search.best_estimator_
best_clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 2))
plot_tree(model, filled=True, feature_names=X.columns)
plt.show()

# prompt: print the number of nodes and depth of the model

# Get the number of nodes and depth of the decision tree
n_nodes = model.tree_.node_count
depth = model.tree_.max_depth

print("Number of nodes:", n_nodes)
print("Depth of the tree:", depth)
# Out:
# Number of nodes: 5
# Depth of the tree: 2

# %%
#------------------------------------------Model Evaluation and Analysis-----------------------------------------------

# %%
'''
  The model gives 100% accuracy at max depth 2.
  So this model is a best fit for the given dataset.
  It says that the heart diseases are exactly predicted using this model.
'''

# %% [markdown]
# Interview Questions:

# %%
'''
1. What are some common hyperparameters of decision tree models, and how do they affect the model's performance?
Common hyperparameters of decision tree models include:
Max Depth: Limits the depth of the tree, controlling model complexity. A shallow tree avoids overfitting but may underfit.
Min Samples Split: Specifies the minimum number of samples required to split a node. Higher values reduce overfitting.
Min Samples Leaf: Defines the minimum samples in a leaf node, smoothing predictions.
Max Features: Limits features considered for splitting, improving generalization.
Criterion: Measures split quality (e.g., Gini index or entropy for classification).
Max Leaf Nodes: Restricts leaf nodes, simplifying the model.
Tuning these balances bias-variance trade-offs, optimizing accuracy and generalization.

2. What is the difference between the Label encoding and One-hot encoding?                                      
Label encoding and one-hot encoding are techniques for converting categorical data into numerical form.
Label Encoding: Assigns a unique integer to each category (e.g., "Red" → 0, "Blue" → 1).
                It’s simple and memory-efficient but can introduce ordinal relationships that may mislead the model.
One-hot Encoding: Represents each category as a binary vector with a single 1 for the category and 0s elsewhere 
               (e.g., "Red" → [1, 0, 0], "Blue" → [0, 1, 0]). It avoids ordinal assumptions but increases dimensionality,
               especially with many categories.
Label encoding suits tree-based models, while one-hot encoding is often better for linear models.
'''
