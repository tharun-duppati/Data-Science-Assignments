# %%
# ---------------------------------1. Data Import and Cleaning:---------------------------------------------------

# %%
import pandas as pd
import numpy as np

# Load the data
df=pd.read_csv("D:\\ExcelR Assignments\\Assgnment 5\\Cardiotocographic.csv")

# Check for missing values
print(df.isnull().sum())

# Handle missing values (e.g., replace with mean, median, or mode)
df.fillna(df.mean(), inplace=True)
print(df)
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# ...

# %%
#----------------------------------------------------2. Statistical Summary:----------------------------------------------

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df[df.columns].median()
# Out:
# LB          133.000000
# AC            0.001668
# FM            0.000000
# UC            0.004484
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.500000
# Width        68.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
#------------------------------------------------3. Data Visualization:----------------------------------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Automatically detect numerical columns
numeric_cols = df.select_dtypes(include='number').columns

# Create a figure and axes
fig, ax = plt.subplots(figsize=(12, 8))

# Plot box plots for each numerical column
sns.boxplot(data=df[numeric_cols], orient='h', ax=ax)

# Customize the plot (optional)
plt.title('Box Plots for Numerical Columns')
plt.xlabel('Value')
plt.ylabel('Column Name')
plt.xticks(rotation=45)
plt.show()

# %%
df["LB"].plot(kind="box",vert=False)
q1=df["LB"].quantile(0.25)
q3=df["LB"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["LB"]<lw) | (df["LB"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: 105.0
# Upper Whisker length: 161.0
# Outliers: 10

# %%
df["AC"].plot(kind="box",vert=False)
q1=df["AC"].quantile(0.25)
q3=df["AC"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["AC"]<lw) | (df["AC"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -0.00840919125
# Upper Whisker length: 0.01401531875
# Outliers: 43

# %%
df["FM"].plot(kind="box",vert=False)
q1=df["FM"].quantile(0.25)
q3=df["FM"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["FM"]<lw) | (df["FM"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -0.003849856875
# Upper Whisker length: 0.006416428125
# Outliers: 347

# %%
df["UC"].plot(kind="box",vert=False)
q1=df["UC"].quantile(0.25)
q3=df["UC"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["UC"]<lw) | (df["UC"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -0.005177445124999999
# Upper Whisker length: 0.013563983874999998
# Outliers: 13

# %%
df["DL"].plot(kind="box",vert=False)
q1=df["DL"].quantile(0.25)
q3=df["DL"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["DL"]<lw) | (df["DL"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -0.004934211
# Upper Whisker length: 0.008223685
# Outliers: 125

# %%
df["DS"].plot(kind="box",vert=False)
q1=df["DS"].quantile(0.25)
q3=df["DS"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["DS"]<lw) | (df["DS"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: 0.0
# Upper Whisker length: 0.0
# Outliers: 141

# %%
df["DP"].plot(kind="box",vert=False)
q1=df["DP"].quantile(0.25)
q3=df["DP"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["DP"]<lw) | (df["DP"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: 0.0
# Upper Whisker length: 0.0
# Outliers: 305

# %%
df["ASTV"].plot(kind="box",vert=False)
q1=df["ASTV"].quantile(0.25)
q3=df["ASTV"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["ASTV"]<lw) | (df["ASTV"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -11.5
# Upper Whisker length: 104.5
# Outliers: 10

# %%
df["MSTV"].plot(kind="box",vert=False)
q1=df["MSTV"].quantile(0.25)
q3=df["MSTV"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["MSTV"]<lw) | (df["MSTV"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -0.8
# Upper Whisker length: 3.2
# Outliers: 80

# %%
df["ALTV"].plot(kind="box",vert=False)
q1=df["ALTV"].quantile(0.25)
q3=df["ALTV"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["ALTV"]<lw) | (df["ALTV"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -16.5
# Upper Whisker length: 27.5
# Outliers: 318

# %%
df["MLTV"].plot(kind="box",vert=False)
q1=df["MLTV"].quantile(0.25)
q3=df["MLTV"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["MLTV"]<lw) | (df["MLTV"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -4.700000000000001
# Upper Whisker length: 20.1
# Outliers: 81

# %%
df["Width"].plot(kind="box",vert=False)
q1=df["Width"].quantile(0.25)
q3=df["Width"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["Width"]<lw) | (df["Width"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -57.5
# Upper Whisker length: 194.5
# Outliers: 10

# %%
df["Tendency"].plot(kind="box",vert=False)
q1=df["Tendency"].quantile(0.25)
q3=df["Tendency"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["Tendency"]<lw) | (df["Tendency"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: -1.5
# Upper Whisker length: 2.5
# Outliers: 10

# %%
df["NSP"].plot(kind="box",vert=False)
q1=df["NSP"].quantile(0.25)
q3=df["NSP"].quantile(0.75)
iqr=q3-q1
lw=q1-1.5 * iqr
uw=q3+1.5 * iqr
print("Lower Whisker length:",lw)
print("Upper Whisker length:",uw)
outliers=df[(df["NSP"]<lw) | (df["NSP"]>uw)]
print("Outliers:",len(outliers))
# Out:
# Lower Whisker length: 1.0
# Upper Whisker length: 1.0
# Outliers: 580

# %%
# Automatically detect numerical columns
numeric_cols = df.select_dtypes(include='number').columns

# Create a figure and subplots
fig, axes = plt.subplots(nrows=len(numeric_cols), ncols=len(numeric_cols), figsize=(52, 72))

# Plot scatter plots for each pair of numerical columns
for i in range(len(numeric_cols)):
    for j in range(len(numeric_cols)):
        if i != j:
            sns.scatterplot(data=df, x=numeric_cols[i], y=numeric_cols[j], ax=axes[i, j])
            axes[i, j].set_title(f'{numeric_cols[i]} vs {numeric_cols[j]}')

plt.tight_layout()
plt.show()

# %%
#---------------------------------------------------4. Pattern Recognition and Insights:-------------------------------------

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
''' In the correlation,
    -MSTV and Width are strong positively correlated.
    -ALTV and Width are strong negatively correlated.
'''

# %%
'''
Interpretations and Insights (Hypothetical, based on common cardiotocographic interpretations):

Fetal Heart Rate (LB): High values might indicate fetal distress, while low values could suggest fetal sleep or decreased oxygenation.
Accelerations (AC): Frequent accelerations are generally a good sign of fetal well-being.
Fetal Movements (FM): Increased fetal movements might indicate fetal distress or discomfort.
Uterine Contractions (UC): Excessive contractions can lead to decreased fetal oxygenation.
Decelerations (DL, DS, DP): These are associated with fetal distress and should be investigated further.
Variability (ASTV, MSTV, ALTV, MLTV): Abnormal variability can indicate fetal compromise.

# %%
#----------------------------------------------------------5. Conclusion:----------------------------------------------------

# %%
'''
Contextual Understanding: The interpretation of these patterns should be done in conjunction with medical expertise and clinical context.
Further Analysis: More advanced statistical techniques like time series analysis, machine learning, or hypothesis testing might be necessary
for deeper insights.
By following these steps and leveraging the power of data visualization and statistical analysis,
we can extract valuable insights from the cardiographic dataset and potentially contribute to better understanding of fetal health.
